# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\acer\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.0.2)

# %%
import numpy as np
from scipy.io.wavfile import write

# Parameters for the beep sound
sample_rate = 44100  # Hz
duration = 0.5  # seconds
frequency = 1000  # Hz

# Generate sine wave
t = np.linspace(0, duration, int(sample_rate * duration), False)
audio_data = 0.5 * np.sin(2 * np.pi * frequency * t)

# Normalize and convert to 16-bit PCM format
audio_data = (audio_data * 32767).astype(np.int16)

# Save the beep as a WAV file
write('beep.wav', sample_rate, audio_data)
print("Beep sound saved as 'beep.wav'")
# Out:
# Beep sound saved as 'beep.wav'

# %%
# !pip install simpleaudio
# Out:
# Collecting simpleaudio
#   Using cached simpleaudio-1.0.4.tar.gz (2.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: simpleaudio
#   Building wheel for simpleaudio (setup.py): started
#   Building wheel for simpleaudio (setup.py): finished with status 'done'
#   Created wheel for simpleaudio: filename=simpleaudio-1.0.4-cp312-cp312-win_amd64.whl size=2039341 sha256=0aa75becee4ae708d625beacf786dc9684ee1a4566a89a88ead4e3adf74d81eb
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\1d\ad\93\be934a93f1ba8922256840f1cf0e59f8a21e2539985616b64f
# Successfully built simpleaudio
# Installing collected packages: simpleaudio
# Successfully installed simpleaudio-1.0.4

# %%
import cv2
import time
import threading
import pygame

# Initialize pygame mixer
pygame.mixer.init()
beep_sound = pygame.mixer.Sound('beep.wav')

# Load Haar Cascades for face and eye detection
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)
eye_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_eye.xml'
)

# Initialize video capture
cap = cv2.VideoCapture(0)

# Timing variables
last_eye_detection = time.time()
ALARM_DURATION = 5  # seconds

# Flag to debounce the beep call
beep_playing = False

def reset_beep():
    global beep_playing
    beep_playing = False

def trigger_beep():
    global beep_playing
    if not beep_playing:
        beep_playing = True
        beep_sound.play()
        # Schedule flag reset after the beep finishes playing
        threading.Timer(beep_sound.get_length(), reset_beep).start()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 3)
    eyes_detected = False

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        # Use only the upper half of the face for eye detection
        roi_gray = gray[y:y + h//2, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)
        if len(eyes) > 0:
            eyes_detected = True
            last_eye_detection = time.time()
        for (ex, ey, ew, eh) in eyes:
            # Draw rectangles on the original frame for clarity
            cv2.rectangle(frame, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 255, 0), 2)

    # If eyes haven't been detected for ALARM_DURATION seconds, trigger a beep
    if time.time() - last_eye_detection > ALARM_DURATION:
        cv2.putText(frame, "WAKE UP!", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        trigger_beep()

    cv2.imshow('Eye Monitor', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import json
import os

class MindReader:
    def __init__(self):
        self.data_file = "mind_data.json"
        self.knowledge = self.load_data()
        self.current_node = self.knowledge
        # Path holds tuples of (parent_node, branch) so we know which branch (yes/no) to update
        self.path = []

    def load_data(self):
        if os.path.exists(self.data_file):
            with open(self.data_file, 'r') as f:
                return json.load(f)
        # Initial tree: a single question with two answers (leaves as strings)
        return {
            "question": "Is it a living person?",
            "yes": "Albert Einstein",
            "no": "Mickey Mouse"
        }

    def save_data(self):
        with open(self.data_file, 'w') as f:
            json.dump(self.knowledge, f, indent=2)

    def reset(self):
        self.current_node = self.knowledge
        self.path = []

    def make_guess(self):
        # At this point, self.current_node should be a leaf (a string guess)
        guess = self.current_node
        print(f"\nI'm ready to blow your mind. Is it... {guess}?")
        response = input("(y/n) > ").lower()
        if response == 'y':
            print("\n🎉 I knew it! My logic is undeniable!")
            return True

        print("\n🤯 Okay, you got me... But help me learn!")
        new_entity = input("Who were you thinking of? > ")
        new_question = input(f"What question would distinguish {new_entity} from {guess}? > ")
        answer = input(f"For {new_entity}, what is the answer to '{new_question}'? (y/n) > ").lower()

        # Create a new decision node to replace the wrong leaf.
        new_node = {"question": new_question}
        if answer == 'y':
            new_node["yes"] = new_entity
            new_node["no"] = guess
        else:
            new_node["yes"] = guess
            new_node["no"] = new_entity

        # Update the parent's branch using the stored path
        if self.path:
            parent, branch = self.path[-1]
            parent[branch] = new_node
        else:
            # If no parent, update the entire knowledge base (happens if the tree was a single leaf)
            self.knowledge = new_node

        self.save_data()
        return False

    def play_round(self):
        self.reset()
        print("\n" + "="*50)
        print("🤖 Think of any real or fictional entity...")
        print("I'll read your mind through logical deduction!")
        print("="*50 + "\n")
        
        # Traverse the decision tree using the user's answers.
        while isinstance(self.current_node, dict) and "question" in self.current_node:
            question = self.current_node["question"]
            response = input(f"{question}\n(y/n) > ").lower()
            # Save the current node and branch chosen to update later if needed
            branch = "yes" if response == 'y' else "no"
            self.path.append((self.current_node, branch))
            self.current_node = self.current_node[branch]

        # At this point, current_node should be a leaf (a guess string)
        if self.make_guess():
            return  # Correct guess; nothing else to do.
        self.save_data()

    def explain_logic(self):
        print("\n🧠 My deduction path:")
        for node, answer in self.path:
            if isinstance(node, dict) and "question" in node:
                print(f"- {node['question']} → {answer.upper()}")
        print("="*50 + "\n")


def main():
    game = MindReader()
    while True:
        game.play_round()
        game.explain_logic()
        again = input("Play again? (y/n) > ").lower()
        if again != 'y':
            print("\n👋 Until next time... Remember, I'm always learning!")
            break

if __name__ == "__main__":
    main()
# Out:
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
# Is it a living person?
# (y/n) >  y
# I'm ready to blow your mind. Is it... Albert Einstein?
# (y/n) >  n
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of? >  My room mate
# What question would distinguish My room mate from Albert Einstein? >  My room mate is not genius
# For My room mate, what is the answer to 'My room mate is not genius '? (y/n) >  y
# 🧠 My deduction path:
# - Is it a living person? → YES
# ==================================================
# Play again? (y/n) >  y
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
# Is it a living person?
# (y/n) >  y
# My room mate is not genius
# (y/n) >  y
# I'm ready to blow your mind. Is it... My room mate?
# (y/n) >  n
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of? >  d
# What question would distinguish d from My room mate? >  d
# For d, what is the answer to 'd'? (y/n) >  d
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# ==================================================
# Play again? (y/n) >  n
# 👋 Until next time... Remember, I'm always learning!

# %%
import json
import os
import random

class MindReader:
    def __init__(self, simulate=False):
        self.data_file = "mind_data.json"
        self.knowledge = self.load_data()
        self.current_node = self.knowledge
        # Path holds tuples of (parent_node, branch) so we know which branch (yes/no) to update later
        self.path = []
        self.simulate = simulate
        # In simulation mode, each round will use a predetermined entity name.
        self.simulated_entity = None

    def load_data(self):
        if os.path.exists(self.data_file):
            with open(self.data_file, 'r') as f:
                return json.load(f)
        # Initial decision tree: a single question with two leaves.
        return {
            "question": "Is it a living person?",
            "yes": "Albert Einstein",
            "no": "Mickey Mouse"
        }

    def save_data(self):
        with open(self.data_file, 'w') as f:
            json.dump(self.knowledge, f, indent=2)

    def reset(self):
        self.current_node = self.knowledge
        self.path = []

    def simulate_input(self, prompt, mode="default", context=None):
        """
        Simulated input based on the mode:
         - "traverse": For questions during tree traversal; returns random 'y' or 'n'.
         - "guess": For the guess prompt; returns 'y' if the guess matches the simulated entity.
         - "teach_entity": Returns the simulated entity name.
         - "teach_question": Generates a distinguishing question.
         - "teach_answer": Returns 'y' to indicate that for the new entity the answer is yes.
        """
        if mode == "traverse":
            # Randomly simulate a yes/no answer
            response = random.choice(['y', 'n'])
            print(f"{prompt}\n(y/n) > {response}")
            return response
        elif mode == "guess":
            # When guessing, if the guess equals our simulated entity, answer 'y'
            if context == self.simulated_entity:
                response = 'y'
            else:
                response = 'n'
            print(f"{prompt}\n(y/n) > {response}")
            return response
        elif mode == "teach_entity":
            # Return the simulated entity for teaching
            print(f"{prompt}\n> {self.simulated_entity}")
            return self.simulated_entity
        elif mode == "teach_question":
            # Generate a simple distinguishing question.
            new_question = f"Is it {self.simulated_entity}?"
            print(f"{prompt}\n> {new_question}")
            return new_question
        elif mode == "teach_answer":
            # For teaching, always return 'y'
            response = 'y'
            print(f"{prompt}\n(y/n) > {response}")
            return response
        else:
            return ""

    def make_guess(self):
        # At this point, current_node is expected to be a leaf (a guess string)
        guess = self.current_node
        prompt = f"\nI'm ready to blow your mind. Is it... {guess}?"
        if self.simulate:
            response = self.simulate_input(prompt, mode="guess", context=guess)
        else:
            response = input(f"{prompt}\n(y/n) > ").lower()
        if response == 'y':
            print("\n🎉 I knew it! My logic is undeniable!")
            return True

        print("\n🤯 Okay, you got me... But help me learn!")
        if self.simulate:
            new_entity = self.simulate_input("Who were you thinking of?", mode="teach_entity")
            new_question = self.simulate_input(
                f"What question would distinguish {new_entity} from {guess}?",
                mode="teach_question"
            )
            answer = self.simulate_input(
                f"For {new_entity}, what is the answer to '{new_question}'?",
                mode="teach_answer"
            )
        else:
            new_entity = input("Who were you thinking of? > ")
            new_question = input(f"What question would distinguish {new_entity} from {guess}? > ")
            answer = input(f"For {new_entity}, what is the answer to '{new_question}'? (y/n) > ").lower()

        old_entity = guess
        # Create a new decision node to replace the wrong guess.
        new_node = {"question": new_question}
        if answer == 'y':
            new_node["yes"] = new_entity
            new_node["no"] = old_entity
        else:
            new_node["yes"] = old_entity
            new_node["no"] = new_entity

        # Update the parent's branch using the stored traversal path.
        if self.path:
            parent, branch = self.path[-1]
            parent[branch] = new_node
        else:
            self.knowledge = new_node

        self.save_data()
        return False

    def play_round(self):
        self.reset()
        print("\n" + "=" * 50)
        print("🤖 Think of any real or fictional entity...")
        print("I'll read your mind through logical deduction!")
        print("=" * 50 + "\n")

        # Traverse the decision tree using the stored questions.
        while isinstance(self.current_node, dict) and "question" in self.current_node:
            question = self.current_node["question"]
            if self.simulate:
                response = self.simulate_input(question, mode="traverse")
            else:
                response = input(f"{question}\n(y/n) > ").lower()
            branch = "yes" if response == 'y' else "no"
            self.path.append((self.current_node, branch))
            self.current_node = self.current_node[branch]

        # At a leaf: attempt to guess.
        if self.make_guess():
            return
        self.save_data()

    def explain_logic(self):
        print("\n🧠 My deduction path:")
        for node, answer in self.path:
            if isinstance(node, dict) and "question" in node:
                print(f"- {node['question']} → {answer.upper()}")
        print("=" * 50 + "\n")


def main():
    # Enable simulation mode.
    game = MindReader(simulate=True)
    rounds = 100
    for i in range(1, rounds + 1):
        print(f"\n--- Round {i} ---")
        # For each round, define a simulated entity that the game must "guess."
        game.simulated_entity = f"Entity{i}"
        game.play_round()
        game.explain_logic()
    print("\nSimulation complete. The knowledge base has been updated over 100 rounds.")

if __name__ == "__main__":
    main()
# Out:
# --- Round 1 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
#
# I'm ready to blow your mind. Is it... d?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity1
# What question would distinguish Entity1 from d?
# > Is it Entity1?
# For Entity1, what is the answer to 'Is it Entity1?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# ==================================================
#
#
# --- Round 2 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Mickey Mouse?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity2
# What question would distinguish Entity2 from Mickey Mouse?
# > Is it Entity2?
# For Entity2, what is the answer to 'Is it Entity2?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# ==================================================
#
#
# --- Round 3 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Albert Einstein?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity3
# What question would distinguish Entity3 from Albert Einstein?
# > Is it Entity3?
# For Entity3, what is the answer to 'Is it Entity3?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# ==================================================
#
#
# --- Round 4 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... d?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity4
# What question would distinguish Entity4 from d?
# > Is it Entity4?
# For Entity4, what is the answer to 'Is it Entity4?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# ==================================================
#
#
# --- Round 5 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity3?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity5
# What question would distinguish Entity5 from Entity3?
# > Is it Entity5?
# For Entity5, what is the answer to 'Is it Entity5?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# ==================================================
#
#
# --- Round 6 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
#
# I'm ready to blow your mind. Is it... My room mate?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity6
# What question would distinguish Entity6 from My room mate?
# > Is it Entity6?
# For Entity6, what is the answer to 'Is it Entity6?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# ==================================================
#
#
# --- Round 7 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity2?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity7
# What question would distinguish Entity7 from Entity2?
# > Is it Entity7?
# For Entity7, what is the answer to 'Is it Entity7?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# ==================================================
#
#
# --- Round 8 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Albert Einstein?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity8
# What question would distinguish Entity8 from Albert Einstein?
# > Is it Entity8?
# For Entity8, what is the answer to 'Is it Entity8?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# ==================================================
#
#
# --- Round 9 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity1?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity9
# What question would distinguish Entity9 from Entity1?
# > Is it Entity9?
# For Entity9, what is the answer to 'Is it Entity9?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# ==================================================
#
#
# --- Round 10 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity5?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity10
# What question would distinguish Entity10 from Entity5?
# > Is it Entity10?
# For Entity10, what is the answer to 'Is it Entity10?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → YES
# ==================================================
#
#
# --- Round 11 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > y
# Is it Entity10?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity5?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity11
# What question would distinguish Entity11 from Entity5?
# > Is it Entity11?
# For Entity11, what is the answer to 'Is it Entity11?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → YES
# - Is it Entity10? → NO
# ==================================================
#
#
# --- Round 12 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Mickey Mouse?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity12
# What question would distinguish Entity12 from Mickey Mouse?
# > Is it Entity12?
# For Entity12, what is the answer to 'Is it Entity12?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# ==================================================
#
#
# --- Round 13 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity7?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity13
# What question would distinguish Entity13 from Entity7?
# > Is it Entity13?
# For Entity13, what is the answer to 'Is it Entity13?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → YES
# ==================================================
#
#
# --- Round 14 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > y
# Is it Entity13?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity7?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity14
# What question would distinguish Entity14 from Entity7?
# > Is it Entity14?
# For Entity14, what is the answer to 'Is it Entity14?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → YES
# - Is it Entity13? → NO
# ==================================================
#
#
# --- Round 15 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Albert Einstein?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity15
# What question would distinguish Entity15 from Albert Einstein?
# > Is it Entity15?
# For Entity15, what is the answer to 'Is it Entity15?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → NO
# ==================================================
#
#
# --- Round 16 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > y
# Is it Entity13?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity13?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity16
# What question would distinguish Entity16 from Entity13?
# > Is it Entity16?
# For Entity16, what is the answer to 'Is it Entity16?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → YES
# - Is it Entity13? → YES
# ==================================================
#
#
# --- Round 17 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity9?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity17
# What question would distinguish Entity17 from Entity9?
# > Is it Entity17?
# For Entity17, what is the answer to 'Is it Entity17?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# ==================================================
#
#
# --- Round 18 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity12?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity18
# What question would distinguish Entity18 from Entity12?
# > Is it Entity18?
# For Entity18, what is the answer to 'Is it Entity18?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# ==================================================
#
#
# --- Round 19 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity3?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity19
# What question would distinguish Entity19 from Entity3?
# > Is it Entity19?
# For Entity19, what is the answer to 'Is it Entity19?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → NO
# ==================================================
#
#
# --- Round 20 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Mickey Mouse?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity20
# What question would distinguish Entity20 from Mickey Mouse?
# > Is it Entity20?
# For Entity20, what is the answer to 'Is it Entity20?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# ==================================================
#
#
# --- Round 21 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity9?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity21
# What question would distinguish Entity21 from Entity9?
# > Is it Entity21?
# For Entity21, what is the answer to 'Is it Entity21?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → NO
# ==================================================
#
#
# --- Round 22 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity6?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity22
# What question would distinguish Entity22 from Entity6?
# > Is it Entity22?
# For Entity22, what is the answer to 'Is it Entity22?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → YES
# ==================================================
#
#
# --- Round 23 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity18?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity23
# What question would distinguish Entity23 from Entity18?
# > Is it Entity23?
# For Entity23, what is the answer to 'Is it Entity23?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# ==================================================
#
#
# --- Round 24 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
# Is it Entity4?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... d?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity24
# What question would distinguish Entity24 from d?
# > Is it Entity24?
# For Entity24, what is the answer to 'Is it Entity24?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# - Is it Entity4? → NO
# ==================================================
#
#
# --- Round 25 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... My room mate?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity25
# What question would distinguish Entity25 from My room mate?
# > Is it Entity25?
# For Entity25, what is the answer to 'Is it Entity25?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → NO
# ==================================================
#
#
# --- Round 26 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity1?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity26
# What question would distinguish Entity26 from Entity1?
# > Is it Entity26?
# For Entity26, what is the answer to 'Is it Entity26?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → NO
# ==================================================
#
#
# --- Round 27 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > n
# Is it Entity25?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... My room mate?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity27
# What question would distinguish Entity27 from My room mate?
# > Is it Entity27?
# For Entity27, what is the answer to 'Is it Entity27?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → NO
# - Is it Entity25? → NO
# ==================================================
#
#
# --- Round 28 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > n
# Is it Entity25?
# (y/n) > n
# Is it Entity27?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity27?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity28
# What question would distinguish Entity28 from Entity27?
# > Is it Entity28?
# For Entity28, what is the answer to 'Is it Entity28?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → NO
# - Is it Entity25? → NO
# - Is it Entity27? → YES
# ==================================================
#
#
# --- Round 29 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity12?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity29
# What question would distinguish Entity29 from Entity12?
# > Is it Entity29?
# For Entity29, what is the answer to 'Is it Entity29?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → NO
# ==================================================
#
#
# --- Round 30 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity2?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity30
# What question would distinguish Entity30 from Entity2?
# > Is it Entity30?
# For Entity30, what is the answer to 'Is it Entity30?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# ==================================================
#
#
# --- Round 31 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > n
# Is it Entity21?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity21?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity31
# What question would distinguish Entity31 from Entity21?
# > Is it Entity31?
# For Entity31, what is the answer to 'Is it Entity31?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → NO
# - Is it Entity21? → YES
# ==================================================
#
#
# --- Round 32 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
# Is it Entity4?
# (y/n) > n
# Is it Entity24?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... d?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity32
# What question would distinguish Entity32 from d?
# > Is it Entity32?
# For Entity32, what is the answer to 'Is it Entity32?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# - Is it Entity4? → NO
# - Is it Entity24? → NO
# ==================================================
#
#
# --- Round 33 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > n
# Is it Entity29?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity29?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity33
# What question would distinguish Entity33 from Entity29?
# > Is it Entity33?
# For Entity33, what is the answer to 'Is it Entity33?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → NO
# - Is it Entity29? → YES
# ==================================================
#
#
# --- Round 34 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > y
# Is it Entity10?
# (y/n) > n
# Is it Entity11?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity5?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity34
# What question would distinguish Entity34 from Entity5?
# > Is it Entity34?
# For Entity34, what is the answer to 'Is it Entity34?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → YES
# - Is it Entity10? → NO
# - Is it Entity11? → NO
# ==================================================
#
#
# --- Round 35 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > n
# Is it Entity15?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity15?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity35
# What question would distinguish Entity35 from Entity15?
# > Is it Entity35?
# For Entity35, what is the answer to 'Is it Entity35?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → NO
# - Is it Entity15? → YES
# ==================================================
#
#
# --- Round 36 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > n
# Is it Entity15?
# (y/n) > y
# Is it Entity35?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity35?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity36
# What question would distinguish Entity36 from Entity35?
# > Is it Entity36?
# For Entity36, what is the answer to 'Is it Entity36?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → NO
# - Is it Entity15? → YES
# - Is it Entity35? → YES
# ==================================================
#
#
# --- Round 37 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > y
# Is it Entity10?
# (y/n) > n
# Is it Entity11?
# (y/n) > n
# Is it Entity34?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity5?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity37
# What question would distinguish Entity37 from Entity5?
# > Is it Entity37?
# For Entity37, what is the answer to 'Is it Entity37?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → YES
# - Is it Entity10? → NO
# - Is it Entity11? → NO
# - Is it Entity34? → NO
# ==================================================
#
#
# --- Round 38 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > n
# Is it Entity26?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity1?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity38
# What question would distinguish Entity38 from Entity1?
# > Is it Entity38?
# For Entity38, what is the answer to 'Is it Entity38?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → NO
# - Is it Entity26? → NO
# ==================================================
#
#
# --- Round 39 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > n
# Is it Entity15?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Albert Einstein?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity39
# What question would distinguish Entity39 from Albert Einstein?
# > Is it Entity39?
# For Entity39, what is the answer to 'Is it Entity39?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → NO
# - Is it Entity15? → NO
# ==================================================
#
#
# --- Round 40 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity23?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity40
# What question would distinguish Entity40 from Entity23?
# > Is it Entity40?
# For Entity40, what is the answer to 'Is it Entity40?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → YES
# ==================================================
#
#
# --- Round 41 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > n
# Is it Entity29?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity12?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity41
# What question would distinguish Entity41 from Entity12?
# > Is it Entity41?
# For Entity41, what is the answer to 'Is it Entity41?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → NO
# - Is it Entity29? → NO
# ==================================================
#
#
# --- Round 42 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity30?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity42
# What question would distinguish Entity42 from Entity30?
# > Is it Entity42?
# For Entity42, what is the answer to 'Is it Entity42?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → YES
# ==================================================
#
#
# --- Round 43 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity20?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity43
# What question would distinguish Entity43 from Entity20?
# > Is it Entity43?
# For Entity43, what is the answer to 'Is it Entity43?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → YES
# ==================================================
#
#
# --- Round 44 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity8?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity44
# What question would distinguish Entity44 from Entity8?
# > Is it Entity44?
# For Entity44, what is the answer to 'Is it Entity44?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → YES
# ==================================================
#
#
# --- Round 45 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > y
# Is it Entity22?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity6?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity45
# What question would distinguish Entity45 from Entity6?
# > Is it Entity45?
# For Entity45, what is the answer to 'Is it Entity45?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → YES
# - Is it Entity22? → NO
# ==================================================
#
#
# --- Round 46 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > y
# Is it Entity42?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity30?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity46
# What question would distinguish Entity46 from Entity30?
# > Is it Entity46?
# For Entity46, what is the answer to 'Is it Entity46?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → YES
# - Is it Entity42? → NO
# ==================================================
#
#
# --- Round 47 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > n
# Is it Entity21?
# (y/n) > y
# Is it Entity31?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity31?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity47
# What question would distinguish Entity47 from Entity31?
# > Is it Entity47?
# For Entity47, what is the answer to 'Is it Entity47?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → NO
# - Is it Entity21? → YES
# - Is it Entity31? → YES
# ==================================================
#
#
# --- Round 48 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity18?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity48
# What question would distinguish Entity48 from Entity18?
# > Is it Entity48?
# For Entity48, what is the answer to 'Is it Entity48?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → NO
# ==================================================
#
#
# --- Round 49 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > y
# Is it Entity42?
# (y/n) > n
# Is it Entity46?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity30?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity49
# What question would distinguish Entity49 from Entity30?
# > Is it Entity49?
# For Entity49, what is the answer to 'Is it Entity49?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → YES
# - Is it Entity42? → NO
# - Is it Entity46? → NO
# ==================================================
#
#
# --- Round 50 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > y
# Is it Entity22?
# (y/n) > n
# Is it Entity45?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity45?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity50
# What question would distinguish Entity50 from Entity45?
# > Is it Entity50?
# For Entity50, what is the answer to 'Is it Entity50?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → YES
# - Is it Entity22? → NO
# - Is it Entity45? → YES
# ==================================================
#
#
# --- Round 51 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > y
# Is it Entity40?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity40?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity51
# What question would distinguish Entity51 from Entity40?
# > Is it Entity51?
# For Entity51, what is the answer to 'Is it Entity51?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → YES
# - Is it Entity40? → YES
# ==================================================
#
#
# --- Round 52 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
# Is it Entity4?
# (y/n) > n
# Is it Entity24?
# (y/n) > n
# Is it Entity32?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... d?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity52
# What question would distinguish Entity52 from d?
# > Is it Entity52?
# For Entity52, what is the answer to 'Is it Entity52?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# - Is it Entity4? → NO
# - Is it Entity24? → NO
# - Is it Entity32? → NO
# ==================================================
#
#
# --- Round 53 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
# Is it Entity4?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity4?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity53
# What question would distinguish Entity53 from Entity4?
# > Is it Entity53?
# For Entity53, what is the answer to 'Is it Entity53?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# - Is it Entity4? → YES
# ==================================================
#
#
# --- Round 54 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity17?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity54
# What question would distinguish Entity54 from Entity17?
# > Is it Entity54?
# For Entity54, what is the answer to 'Is it Entity54?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → YES
# ==================================================
#
#
# --- Round 55 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > n
# Is it Entity21?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity9?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity55
# What question would distinguish Entity55 from Entity9?
# > Is it Entity55?
# For Entity55, what is the answer to 'Is it Entity55?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → NO
# - Is it Entity21? → NO
# ==================================================
#
#
# --- Round 56 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > n
# Is it Entity48?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity18?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity56
# What question would distinguish Entity56 from Entity18?
# > Is it Entity56?
# For Entity56, what is the answer to 'Is it Entity56?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → NO
# - Is it Entity48? → NO
# ==================================================
#
#
# --- Round 57 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > n
# Is it Entity4?
# (y/n) > y
# Is it Entity53?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity53?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity57
# What question would distinguish Entity57 from Entity53?
# > Is it Entity57?
# For Entity57, what is the answer to 'Is it Entity57?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → NO
# - Is it Entity4? → YES
# - Is it Entity53? → YES
# ==================================================
#
#
# --- Round 58 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Mickey Mouse?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity58
# What question would distinguish Entity58 from Mickey Mouse?
# > Is it Entity58?
# For Entity58, what is the answer to 'Is it Entity58?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → NO
# ==================================================
#
#
# --- Round 59 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > n
# Is it Entity58?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity58?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity59
# What question would distinguish Entity59 from Entity58?
# > Is it Entity59?
# For Entity59, what is the answer to 'Is it Entity59?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → NO
# - Is it Entity58? → YES
# ==================================================
#
#
# --- Round 60 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > y
# Is it Entity22?
# (y/n) > n
# Is it Entity45?
# (y/n) > n
#
# ...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > y
# Is it Entity42?
# (y/n) > n
# Is it Entity46?
# (y/n) > n
# Is it Entity49?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity30?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity83
# What question would distinguish Entity83 from Entity30?
# > Is it Entity83?
# For Entity83, what is the answer to 'Is it Entity83?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → YES
# - Is it Entity42? → NO
# - Is it Entity46? → NO
# - Is it Entity49? → NO
# ==================================================
#
#
# --- Round 84 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > y
# Is it Entity40?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity23?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity84
# What question would distinguish Entity84 from Entity23?
# > Is it Entity84?
# For Entity84, what is the answer to 'Is it Entity84?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → YES
# - Is it Entity40? → NO
# ==================================================
#
#
# --- Round 85 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > y
# Is it Entity18?
# (y/n) > y
# Is it Entity23?
# (y/n) > n
# Is it Entity48?
# (y/n) > y
# Is it Entity65?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity65?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity85
# What question would distinguish Entity85 from Entity65?
# > Is it Entity85?
# For Entity85, what is the answer to 'Is it Entity85?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → YES
# - Is it Entity18? → YES
# - Is it Entity23? → NO
# - Is it Entity48? → YES
# - Is it Entity65? → YES
# ==================================================
#
#
# --- Round 86 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > n
# Is it Entity64?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity64?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity86
# What question would distinguish Entity86 from Entity64?
# > Is it Entity86?
# For Entity86, what is the answer to 'Is it Entity86?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → NO
# - Is it Entity64? → YES
# ==================================================
#
#
# --- Round 87 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > y
# Is it Entity43?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity20?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity87
# What question would distinguish Entity87 from Entity20?
# > Is it Entity87?
# For Entity87, what is the answer to 'Is it Entity87?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → YES
# - Is it Entity43? → NO
# ==================================================
#
#
# --- Round 88 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > y
# Is it Entity10?
# (y/n) > n
# Is it Entity11?
# (y/n) > n
# Is it Entity34?
# (y/n) > n
# Is it Entity37?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity37?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity88
# What question would distinguish Entity88 from Entity37?
# > Is it Entity88?
# For Entity88, what is the answer to 'Is it Entity88?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → YES
# - Is it Entity10? → NO
# - Is it Entity11? → NO
# - Is it Entity34? → NO
# - Is it Entity37? → YES
# ==================================================
#
#
# --- Round 89 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > n
# Is it Entity30?
# (y/n) > y
# Is it Entity42?
# (y/n) > n
# Is it Entity46?
# (y/n) > y
# Is it Entity76?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity46?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity89
# What question would distinguish Entity89 from Entity46?
# > Is it Entity89?
# For Entity89, what is the answer to 'Is it Entity89?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → NO
# - Is it Entity30? → YES
# - Is it Entity42? → NO
# - Is it Entity46? → YES
# - Is it Entity76? → NO
# ==================================================
#
#
# --- Round 90 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > y
# Is it Entity43?
# (y/n) > y
# Is it Entity66?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity66?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity90
# What question would distinguish Entity90 from Entity66?
# > Is it Entity90?
# For Entity90, what is the answer to 'Is it Entity90?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → YES
# - Is it Entity43? → YES
# - Is it Entity66? → YES
# ==================================================
#
#
# --- Round 91 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > n
# Is it Entity21?
# (y/n) > n
# Is it Entity55?
# (y/n) > y
# Is it Entity68?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity55?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity91
# What question would distinguish Entity91 from Entity55?
# > Is it Entity91?
# For Entity91, what is the answer to 'Is it Entity91?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → NO
# - Is it Entity21? → NO
# - Is it Entity55? → YES
# - Is it Entity68? → NO
# ==================================================
#
#
# --- Round 92 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > n
# Is it Entity58?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Mickey Mouse?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity92
# What question would distinguish Entity92 from Mickey Mouse?
# > Is it Entity92?
# For Entity92, what is the answer to 'Is it Entity92?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → NO
# - Is it Entity58? → NO
# ==================================================
#
#
# --- Round 93 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > y
# Is it Entity7?
# (y/n) > y
# Is it Entity13?
# (y/n) > y
# Is it Entity16?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity16?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity93
# What question would distinguish Entity93 from Entity16?
# > Is it Entity93?
# For Entity93, what is the answer to 'Is it Entity93?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → YES
# - Is it Entity7? → YES
# - Is it Entity13? → YES
# - Is it Entity16? → YES
# ==================================================
#
#
# --- Round 94 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > n
# Is it Entity2?
# (y/n) > n
# Is it Entity12?
# (y/n) > n
# Is it Entity20?
# (y/n) > n
# Is it Entity58?
# (y/n) > n
# Is it Entity92?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity92?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity94
# What question would distinguish Entity94 from Entity92?
# > Is it Entity94?
# For Entity94, what is the answer to 'Is it Entity94?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → NO
# - Is it Entity2? → NO
# - Is it Entity12? → NO
# - Is it Entity20? → NO
# - Is it Entity58? → NO
# - Is it Entity92? → YES
# ==================================================
#
#
# --- Round 95 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > y
# Is it Entity22?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity22?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity95
# What question would distinguish Entity95 from Entity22?
# > Is it Entity95?
# For Entity95, what is the answer to 'Is it Entity95?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → YES
# - Is it Entity22? → YES
# ==================================================
#
#
# --- Round 96 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > y
# Is it Entity6?
# (y/n) > n
# Is it Entity25?
# (y/n) > y
# Is it Entity69?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity25?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity96
# What question would distinguish Entity96 from Entity25?
# > Is it Entity96?
# For Entity96, what is the answer to 'Is it Entity96?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → YES
# - Is it Entity6? → NO
# - Is it Entity25? → YES
# - Is it Entity69? → NO
# ==================================================
#
#
# --- Round 97 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > n
# Is it Entity8?
# (y/n) > n
# Is it Entity15?
# (y/n) > y
# Is it Entity35?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity15?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity97
# What question would distinguish Entity97 from Entity15?
# > Is it Entity97?
# For Entity97, what is the answer to 'Is it Entity97?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → NO
# - Is it Entity8? → NO
# - Is it Entity15? → YES
# - Is it Entity35? → NO
# ==================================================
#
#
# --- Round 98 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > n
# Is it Entity19?
# (y/n) > y
# Is it Entity80?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity80?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity98
# What question would distinguish Entity98 from Entity80?
# > Is it Entity98?
# For Entity98, what is the answer to 'Is it Entity98?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → NO
# - Is it Entity19? → YES
# - Is it Entity80? → YES
# ==================================================
#
#
# --- Round 99 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > y
# d
# (y/n) > n
# Is it Entity1?
# (y/n) > y
# Is it Entity9?
# (y/n) > y
# Is it Entity17?
# (y/n) > y
# Is it Entity54?
# (y/n) > y
# Is it Entity77?
# (y/n) > n
#
# I'm ready to blow your mind. Is it... Entity54?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity99
# What question would distinguish Entity99 from Entity54?
# > Is it Entity99?
# For Entity99, what is the answer to 'Is it Entity99?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → YES
# - d → NO
# - Is it Entity1? → YES
# - Is it Entity9? → YES
# - Is it Entity17? → YES
# - Is it Entity54? → YES
# - Is it Entity77? → NO
# ==================================================
#
#
# --- Round 100 ---
#
# ==================================================
# 🤖 Think of any real or fictional entity...
# I'll read your mind through logical deduction!
# ==================================================
#
# Is it a living person?
# (y/n) > y
# My room mate is not genius
# (y/n) > n
# Is it Entity3?
# (y/n) > y
# Is it Entity5?
# (y/n) > n
# Is it Entity19?
# (y/n) > n
# Is it Entity73?
# (y/n) > y
#
# I'm ready to blow your mind. Is it... Entity73?
# (y/n) > n
#
# 🤯 Okay, you got me... But help me learn!
# Who were you thinking of?
# > Entity100
# What question would distinguish Entity100 from Entity73?
# > Is it Entity100?
# For Entity100, what is the answer to 'Is it Entity100?'?
# (y/n) > y
#
# 🧠 My deduction path:
# - Is it a living person? → YES
# - My room mate is not genius  → NO
# - Is it Entity3? → YES
# - Is it Entity5? → NO
# - Is it Entity19? → NO
# - Is it Entity73? → YES
# ==================================================
#
#
# Simulation complete. The knowledge base has been updated over 100 rounds.
